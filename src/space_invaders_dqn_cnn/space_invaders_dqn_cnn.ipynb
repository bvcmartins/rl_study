# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
import gymnasium as gym
import matplotlib.pyplot as plt
from IPython.display import clear_output
import mlflow
import mlflow.pytorch
import wandb
import os
from dotenv import load_dotenv
from pathlib import Path

# Import comprehensive logging utilities (now all in one file)
from logging_utils import *

# %%
import ale_py
gym.register_envs(ale_py)

# %%
class ConvDQN(nn.Module):
    def __init__(self, input_channels, action_size):
        super(ConvDQN, self).__init__()
        
        self.conv = nn.Sequential(
            nn.Conv2d(input_channels, 32, kernel_size=8, stride=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        
        # Calculate correct feature size dynamically
        self.feature_size = self._get_conv_output_size()
        
        self.fc = nn.Sequential(
            nn.Linear(self.feature_size, 512),
            nn.ReLU(),
            nn.Linear(512, action_size)
        )
    
    def _get_conv_output_size(self):
        """Calculate the output size of conv layers"""
        with torch.no_grad():
            dummy_input = torch.zeros(1, 2, 84, 84)  # 1 batch size, 2 channels, 84x84
            conv_output = self.conv(dummy_input)
            return conv_output.numel() // conv_output.size(0)  # Flatten size per sample
    
    def forward(self, x):
        x = self.conv(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)
    
    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))
    
    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        state, action, reward, next_state, done = zip(*batch)
        return np.array(state), action, reward, np.array(next_state), done
    
    def __len__(self):
        return len(self.buffer)

def preprocess_frame(frame):
    import cv2
    gray = np.mean(frame, axis=2).astype(np.uint8)
    cropped = gray[34:194, :]
    resized = cv2.resize(cropped, (84, 84), interpolation=cv2.INTER_AREA)
    return resized.astype(np.float32) / 255.0

class FrameStack:
    def __init__(self, num_frames=2):
        self.num_frames = num_frames
        self.frames = deque(maxlen=num_frames)
    
    def reset(self, frame):
        processed_frame = preprocess_frame(frame)
        for _ in range(self.num_frames):
            self.frames.append(processed_frame)
        return self.get_stacked()
    
    def step(self, frame):
        processed_frame = preprocess_frame(frame)
        self.frames.append(processed_frame)
        return self.get_stacked()
    
    def get_stacked(self):
        return np.stack(list(self.frames), axis=0)

# %%
# Global hyperparameters optimized for Space Invaders
LEARNING_RATE = 0.0001  # Slightly higher LR for Space Invaders
GAMMA = 0.99
EPSILON_START = 1.0
EPSILON_MIN = 0.01
EPSILON_DECAY = 0.995
BATCH_SIZE = 64
BUFFER_SIZE = 100000
TARGET_UPDATE = 1000  # Update every 1000 steps
MEAN_REWARD_BOUND = 500  # Space Invaders target (much lower than Defender)
FRAME_SKIP = 4
INPUT_CHANNELS = 2
FRAME_STACK = 2

# Adaptive training parameters
CONVERGENCE_THRESHOLD = 400  # When to start adaptive epsilon decay
ADAPTIVE_EPSILON_DECAY = 0.999  # Faster decay when close to convergence

# Unified logging frequency
LOG_FREQ = 100  # Log comprehensive analysis every 100 episodes
GRADIENT_LOG_FREQ = 500  # Log gradients every 500 steps

# Architecture and logging configuration
ARCHITECTURE_NAME = "CNN-DQN-SpaceInvaders"
ARCHITECTURE_TYPE = "original"  # "original" for 32-64-64 architecture
MODEL_FILTERS = "32-64-64"

# Loss function configuration - USING HUBER LOSS FOR STABILITY
USE_HUBER_LOSS = True  # Use Huber loss instead of MSE

# Setup hyperparameters dictionary - SINGLE SOURCE OF TRUTH
HYPERPARAMETERS = {
    "learning_rate": LEARNING_RATE,
    "gamma": GAMMA,
    "epsilon_start": EPSILON_START,
    "epsilon_min": EPSILON_MIN,
    "epsilon_decay": EPSILON_DECAY,
    "adaptive_epsilon_decay": ADAPTIVE_EPSILON_DECAY,
    "convergence_threshold": CONVERGENCE_THRESHOLD,
    "batch_size": BATCH_SIZE,
    "buffer_size": BUFFER_SIZE,
    "target_update": TARGET_UPDATE,
    "mean_reward_bound": MEAN_REWARD_BOUND,
    "frame_skip": FRAME_SKIP,
    "input_channels": INPUT_CHANNELS,
    "frame_stack": FRAME_STACK,
    "architecture": ARCHITECTURE_NAME,
    "model_filters": MODEL_FILTERS,
    "architecture_type": ARCHITECTURE_TYPE,
    "game": "SpaceInvaders",
    "use_huber_loss": USE_HUBER_LOSS,
    # Enhanced logging configuration
    "log_freq": LOG_FREQ,
    "gradient_log_freq": GRADIENT_LOG_FREQ,
    "comprehensive_monitoring": True,
    "weight_bias_analysis": True
}

# Set up directories for artifacts using relative paths
RL_STUDY_DIR = Path(__file__).resolve().parent.parent.parent if '__file__' in globals() else Path.cwd().parent.parent
MLFLOW_TRACKING_URI = RL_STUDY_DIR / 'mlruns'
WANDB_DIR = RL_STUDY_DIR / 'wandb'
BASE_ARTIFACTS_DIR = RL_STUDY_DIR / 'artifacts'

# Configure MLflow to use local tracking
mlflow.set_tracking_uri(f'file://{MLFLOW_TRACKING_URI}')

# Configure wandb to use local directory
os.environ['WANDB_DIR'] = str(WANDB_DIR)
WANDB_DIR.mkdir(exist_ok=True)
BASE_ARTIFACTS_DIR.mkdir(exist_ok=True)
MLFLOW_TRACKING_URI.mkdir(exist_ok=True)

# Initialize wandb with unified project structure
load_dotenv(RL_STUDY_DIR / '.env')
wandb_key = os.getenv('WANDB_KEY')
wandb.login(key=wandb_key)

wandb.init(
    project="space_invaders_dqn_training",  # Space Invaders project
    name="space_invaders_cnn_dqn_v1",  # Initial version
    dir=str(WANDB_DIR),
    config=HYPERPARAMETERS  # Use single source of truth
)
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/bmartins/.netrc
# wandb: Currently logged in as: bmartins to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/home/bmartins/dev/rl_study/wandb/wandb/run-20260109_221744-i52u9frw</code>
# Syncing run <strong><a href='https://wandb.ai/bmartins/space_invaders_dqn_training/runs/i52u9frw' target="_blank">space_invaders_cnn_dqn_v1</a></strong> to <a href='https://wandb.ai/bmartins/space_invaders_dqn_training' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/bmartins/space_invaders_dqn_training' target="_blank">https://wandb.ai/bmartins/space_invaders_dqn_training</a>
#  View run at <a href='https://wandb.ai/bmartins/space_invaders_dqn_training/runs/i52u9frw' target="_blank">https://wandb.ai/bmartins/space_invaders_dqn_training/runs/i52u9frw</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/bmartins/space_invaders_dqn_training/runs/i52u9frw?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>
# wandb: WARNING Tried to log to step 0 that is less than the current step 502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 1 that is less than the current step 504. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 2 that is less than the current step 1003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 3 that is less than the current step 1502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4 that is less than the current step 2003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 5 that is less than the current step 2502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 6 that is less than the current step 3502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 7 that is less than the current step 3504. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 8 that is less than the current step 4502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 9 that is less than the current step 5003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 10 that is less than the current step 5005. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 11 that is less than the current step 5502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 12 that is less than the current step 6003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 13 that is less than the current step 7003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 14 that is less than the current step 7005. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 15 that is less than the current step 7502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 16 that is less than the current step 8003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 17 that is less than the current step 8502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 18 that is less than the current step 9003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 19 that is less than the current step 9502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 20 that is less than the current step 10003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 21 that is less than the current step 10006. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 22 that is less than the current step 10502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 23 that is less than the current step 11003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 24 that is less than the current step 12003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 25 that is less than the current step 12502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 26 that is less than the current step 13003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 27 that is less than the current step 13502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 28 that is less than the current step 14502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 29 that is less than the current step 14504. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 30 that is less than the current step 15502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 31 that is less than the current step 15505. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 32 that is less than the current step 16003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 33 that is less than the current step 16502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 34 that is less than the current step 17003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 35 that is less than the current step 17502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 36 that is less than the current step 18003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 37 that is less than the current step 18502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 38 that is less than the current step 19502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 39 that is less than the current step 20003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 40 that is less than the current step 20502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 41 that is less than the current step 21003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 42 that is less than the current step 22003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 43 that is less than the current step 22502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 44 that is less than the current step 23502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 45 that is less than the current step 24003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 46 that is less than the current step 24502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 47 that is less than the current step 25502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 48 that is less than the current step 26003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 49 that is less than the current step 26502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 50 that is less than the current step 27003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 51 that is less than the current step 27502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 52 that is less than the current step 27504. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 53 that is less than the current step 28003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 54 that is less than the current step 29003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 55 that is less than the current step 29502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 56 that is less than the current step 29504. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 57 that is less than the current step 30502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 58 that is less than the current step 30504. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 59 that is less than the current step 31003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 60 that is less than the current step 31502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 61 that is less than the current step 32502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 62 that is less than the current step 33003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 63 that is less than the current step 33502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 64 that is less than the current step 34003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 65 that is less than the current step 34502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 66 that is less than the current step 35003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 67 that is less than the current step 36003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 68 that is less than the current step 36502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 69 that is less than the current step 37502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 70 that is less than the current step 38003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 71 that is less than the current step 38502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 72 that is less than the current step 39003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 73 that is less than the current step 39502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 74 that is less than the current step 40003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 75 that is less than the current step 41003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 76 that is less than the current step 41502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 77 that is less than the current step 42003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 78 that is less than the current step 42502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 79 that is less than the current step 43003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 80 that is less than the current step 43502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 81 that is less than the current step 44003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 82 that is less than the current step 44005. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 83 that is less than the current step 45003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 84 that is less than the current step 45502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 85 that is less than the current step 46003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 86 that is less than the current step 46502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 87 that is less than the current step 47003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 88 that is less than the current step 47502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 89 that is less than the current step 48003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 90 that is less than the current step 48005. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 91 that is less than the current step 48502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 92 that is less than the current step 49003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 93 that is less than the current step 50003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 94 that is less than the current step 50005. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 95 that is less than the current step 50502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 96 that is less than the current step 51003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 97 that is less than the current step 51502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 98 that is less than the current step 52003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 99 that is less than the current step 52005. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 53003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 53004. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 101 that is less than the current step 54003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 102 that is less than the current step 54502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 103 that is less than the current step 55003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 104 that is less than the current step 55502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 105 that is less than the current step 56003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 106 that is less than the current step 56502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 107 that is less than the current step 57003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 108 that is less than the current step 57502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 109 that is less than the current step 58003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 110 that is less than the current step 58502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 111 that is less than the current step 59003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 112 that is less than the current step 59502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 113 that is less than the current step 60003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 114 that is less than the current step 60502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 115 that is less than the current step 61003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 116 that is less than the current step 61502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 117 that is less than the current step 62502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 118 that is less than the current step 63003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 119 that is less than the current step 63502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 120 that is less than the current step 64003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 121 that is less than the current step 64502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 122 that is less than the current step 65003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 123 that is less than the current step 65502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 124 that is less than the current step 66502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 125 that is less than the current step 67003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 126 that is less than the current step 68003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 127 that is less than the current step 68502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 128 that is less than the current step 69003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 129 that is less than the current step 69502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 130 that is less than the current step 70003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 131 that is less than the current step 70502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 132 that is less than the current step 71003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 133 that is less than the current step 71502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 134 that is less than the current step 72003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 135 that is less than the current step 72502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 136 that is less than the current step 73003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 137 that is less than the current step 73502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 138 that is less than the current step 74003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 139 that is less than the current step 74502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 140 that is less than the current step 75003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 141 that is less than the current step 75502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 142 that is less than the current step 76003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 143 that is less than the current step 76502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 144 that is less than the current step 77502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 145 that is less than the current step 78003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 146 that is less than the current step 78502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 147 that is less than the current step 79003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 148 that is less than the current step 80003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 149 that is less than the current step 80502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 150 that is less than the current step 81003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 151 that is less than the current step 81502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 152 that is less than the current step 82003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 153 that is less than the current step 82502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 154 that is less than the current step 83003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 155 that is less than the current step 83502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 156 that is less than the current step 84003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 157 that is less than the current step 84502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 158 that is less than the current step 85003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 159 that is less than the current step 85502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 160 that is less than the current step 86003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 161 that is less than the current step 87003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 162 that is less than the current step 88003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 163 that is less than the current step 88502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 164 that is less than the current step 89003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 165 that is less than the current step 89005. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 166 that is less than the current step 90003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 167 that is less than the current step 90502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 168 that is less than the current step 91502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 169 that is less than the current step 91504. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 170 that is less than the current step 92502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 171 that is less than the current step 93003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 172 that is less than the current step 93502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 173 that is less than the current step 94003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 174 that is less than the current step 94502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 175 that is less than the current step 95003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 176 that is less than the current step 95502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 177 that is less than the current step 96502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 178 that is less than the current step 97502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 179 that is less than the current step 98003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 180 that is less than the current step 98502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 181 that is less than the current step 99003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 182 that is less than the current step 99502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 183 that is less than the current step 100003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 184 that is less than the current step 100005. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 185 that is less than the current step 100502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 186 that is less than the current step 101003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 187 that is less than the current step 101502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 188 that is less than the current step 102003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 189 that is less than the current step 102502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 190 that is less than the current step 103003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 191 that is less than the current step 103502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 192 that is less than the current step 104003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 193 that is less than the current step 104502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 194 that is less than the current step 105003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 195 that is less than the current step 105502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 196 that is less than the current step 106003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 197 that is less than the current step 106502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 198 that is less than the current step 107003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 199 that is less than the current step 108003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 200 that is less than the current step 108502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 200 that is less than the current step 108503. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 201 that is less than the current step 109003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 202 that is less than the current step 109502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 203 that is less than the current step 110003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 204 that is less than the current step 110502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 205 that is less than the current step 111003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 206 that is less than the current step 112003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 207 that is less than the current step 112502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 208 that is less than the current step 113003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 209 that is less than the current step 114003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 210 that is less than the current step 114502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 211 that is less than the current step 115502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 212 that is less than the current step 116003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 213 that is less than the current step 116502. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 214 that is less than the current step 117003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 215 that is less than the current step 118003. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# ...
# wandb: WARNING Tried to log to step 4909 that is less than the current step 3422002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4910 that is less than the current step 3422501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4911 that is less than the current step 3423002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4912 that is less than the current step 3424002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4913 that is less than the current step 3424501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4914 that is less than the current step 3425501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4915 that is less than the current step 3426501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4916 that is less than the current step 3427002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4917 that is less than the current step 3428002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4918 that is less than the current step 3429002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4919 that is less than the current step 3430002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4920 that is less than the current step 3431002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4921 that is less than the current step 3431501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4922 that is less than the current step 3432501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4923 that is less than the current step 3433501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4924 that is less than the current step 3434002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4925 that is less than the current step 3435002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4926 that is less than the current step 3436002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4927 that is less than the current step 3437002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4928 that is less than the current step 3437501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4929 that is less than the current step 3438501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4930 that is less than the current step 3439002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4931 that is less than the current step 3440002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4932 that is less than the current step 3441002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4933 that is less than the current step 3441501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4934 that is less than the current step 3442002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4935 that is less than the current step 3442501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4936 that is less than the current step 3443501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4937 that is less than the current step 3444002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4938 that is less than the current step 3445002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4939 that is less than the current step 3445501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4940 that is less than the current step 3446002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4941 that is less than the current step 3447002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4942 that is less than the current step 3447501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4943 that is less than the current step 3448501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4944 that is less than the current step 3449501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4945 that is less than the current step 3450002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4946 that is less than the current step 3451002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4947 that is less than the current step 3452002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4948 that is less than the current step 3452501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4949 that is less than the current step 3453002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4950 that is less than the current step 3454002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4951 that is less than the current step 3454501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4952 that is less than the current step 3455501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4953 that is less than the current step 3456002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4954 that is less than the current step 3457002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4955 that is less than the current step 3458002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4956 that is less than the current step 3458501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4957 that is less than the current step 3459002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4958 that is less than the current step 3460002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4959 that is less than the current step 3460501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4960 that is less than the current step 3461002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4961 that is less than the current step 3462002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4962 that is less than the current step 3462501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4963 that is less than the current step 3463002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4964 that is less than the current step 3463501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4965 that is less than the current step 3464501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4966 that is less than the current step 3465002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4967 that is less than the current step 3466002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4968 that is less than the current step 3467002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4969 that is less than the current step 3468002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4970 that is less than the current step 3468501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4971 that is less than the current step 3469501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4972 that is less than the current step 3470501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4973 that is less than the current step 3471002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4974 that is less than the current step 3472002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4975 that is less than the current step 3472501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4976 that is less than the current step 3473501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4977 that is less than the current step 3474501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4978 that is less than the current step 3475002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4979 that is less than the current step 3475501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4980 that is less than the current step 3476501. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4981 that is less than the current step 3477002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4982 that is less than the current step 3478002. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.

# %%
# All logging functions are now imported from logging_utils.py

# %%
def train_dqn():
    # End any active runs first
    if mlflow.active_run():
        mlflow.end_run()
    
    # MLflow experiment setup - unified with wandb name
    mlflow.set_experiment("space_invaders_dqn_training")
    
    with mlflow.start_run():
        # Create artifacts directory using MLflow run ID and rl_study structure
        run_id = mlflow.active_run().info.run_id
        artifacts_dir = BASE_ARTIFACTS_DIR / f"run_{run_id}"
        artifacts_dir.mkdir(parents=True, exist_ok=True)
        print(f"Artifacts will be saved to: {artifacts_dir}")
        
        env = gym.make('SpaceInvadersNoFrameskip-v4')  # Space Invaders game
        
        # Use global hyperparameters
        action_size = env.action_space.n
        lr = LEARNING_RATE
        gamma = GAMMA
        epsilon = EPSILON_START
        epsilon_min = EPSILON_MIN
        epsilon_decay = EPSILON_DECAY
        adaptive_epsilon_decay = ADAPTIVE_EPSILON_DECAY
        convergence_threshold = CONVERGENCE_THRESHOLD
        batch_size = BATCH_SIZE
        buffer_size = BUFFER_SIZE
        target_update = TARGET_UPDATE
        mean_reward_bound = MEAN_REWARD_BOUND
        frame_skip = FRAME_SKIP
        
        # Log hyperparameters using external function
        log_hyperparameters(str(artifacts_dir), HYPERPARAMETERS)
        
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print(f"Using device: {device}")
        
        main_net = ConvDQN(input_channels=INPUT_CHANNELS, action_size=action_size).to(device)
        target_net = ConvDQN(input_channels=INPUT_CHANNELS, action_size=action_size).to(device)
        target_net.load_state_dict(main_net.state_dict())
        
        # Setup enhanced weight tracking using logging utils
        setup_weight_tracking(main_net, log_freq=GRADIENT_LOG_FREQ, log_all=True)
        
        # Log model info using external function
        total_params = log_model_info(main_net, device, ARCHITECTURE_NAME)
        
        optimizer = optim.Adam(main_net.parameters(), lr=lr)
        
        # Add learning rate scheduler for stability
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5000, gamma=0.8)
        
        # Choose loss function based on configuration
        if USE_HUBER_LOSS:
            loss_fn = nn.SmoothL1Loss()  # Huber loss for stability
            print("Using Huber Loss (SmoothL1Loss) for better stability")
        else:
            loss_fn = nn.MSELoss()
            print("Using MSE Loss")
        
        buffer = ReplayBuffer(buffer_size)
        
        episode_rewards = []
        mean_rewards = []
        episode = 0
        total_steps = 0
        
        while True:
            state, _ = env.reset()
            frame_stack = FrameStack(FRAME_STACK)
            stacked_state = frame_stack.reset(state)
            total_reward = 0
            done = False
            step_count = 0
            episode_losses = []
            
            while not done:
                if random.random() > epsilon:
                    with torch.no_grad():
                        state_tensor = torch.FloatTensor(stacked_state).unsqueeze(0).to(device)
                        q_values = main_net(state_tensor)
                        action = q_values.max(1)[1].item()
                else:
                    action = env.action_space.sample()
                
                step_reward = 0
                for _ in range(frame_skip):
                    next_state, reward, terminated, truncated, _ = env.step(action)
                    step_reward += reward
                    if terminated or truncated:
                        break
                
                done = terminated or truncated
                next_stacked_state = frame_stack.step(next_state)
                
                buffer.push(stacked_state, action, step_reward, next_stacked_state, done)
                stacked_state = next_stacked_state
                total_reward += step_reward
                step_count += 1
                total_steps += 1
                
                if len(buffer) > batch_size:
                    states, actions, rewards, next_states, dones = buffer.sample(batch_size)
                    
                    states = torch.FloatTensor(states).to(device)
                    actions = torch.LongTensor(actions).to(device)
                    rewards = torch.FloatTensor(rewards).to(device)
                    next_states = torch.FloatTensor(next_states).to(device)
                    dones = torch.BoolTensor(dones).to(device)
                    
                    current_q_values = main_net(states).gather(1, actions.unsqueeze(1))
                    
                    with torch.no_grad():
                        next_q_values = target_net(next_states).max(1)[0]
                        target_q_values = rewards + (gamma * next_q_values * ~dones)
                    
                    # Use configured loss function (Huber or MSE)
                    loss = loss_fn(current_q_values.squeeze(), target_q_values)
                    episode_losses.append(loss.item())
                    
                    optimizer.zero_grad()
                    loss.backward()
                    torch.nn.utils.clip_grad_norm_(main_net.parameters(), max_norm=10)
                    optimizer.step()
                    
                    # Enhanced gradient logging
                    if total_steps % GRADIENT_LOG_FREQ == 0:
                        log_training_step(loss.item(), episode, step_count)
                        log_layer_wise_gradient_norms(main_net, total_steps)
                        
                        # Log weight and bias norms during training
                        current_weight_norms = {}
                        current_bias_norms = {}
                        for name, param in main_net.named_parameters():
                            if param.requires_grad:
                                if 'bias' in name:
                                    current_bias_norms[f"bias_norms/{name}"] = param.data.norm().item()
                                else:
                                    current_weight_norms[f"weight_norms/{name}"] = param.data.norm().item()
                        
                        wandb.log({
                            **current_weight_norms,
                            **current_bias_norms,
                            "training/total_steps": total_steps,
                            "training/episode": episode,
                            "training/learning_rate": scheduler.get_last_lr()[0]
                        })
                    
                    # Update target network every TARGET_UPDATE steps (not episodes)
                    if total_steps % target_update == 0:
                        target_net.load_state_dict(main_net.state_dict())
                        wandb.log({"training/target_network_update": 1, "training/total_steps": total_steps})
            
            # Step learning rate scheduler
            if episode % 100 == 0:
                scheduler.step()
            
            # Adaptive epsilon decay - decay faster when close to convergence
            if epsilon > epsilon_min:
                mean_reward_current = np.mean(episode_rewards[-100:]) if len(episode_rewards) >= 100 else np.mean(episode_rewards) if episode_rewards else 0
                
                if mean_reward_current > convergence_threshold:
                    # Use faster decay when close to convergence
                    epsilon *= adaptive_epsilon_decay
                    wandb.log({"training/adaptive_mode": 1})
                else:
                    # Use normal decay otherwise
                    epsilon *= epsilon_decay
                    wandb.log({"training/adaptive_mode": 0})

            episode_rewards.append(total_reward)
            mean_reward = np.mean(episode_rewards[-100:]) if len(episode_rewards) >= 100 else np.mean(episode_rewards)
            
            # Log episode metrics with loss information
            episode_loss_avg = np.mean(episode_losses) if episode_losses else 0.0
            log_episode_metrics(total_reward, mean_reward, epsilon, len(buffer), step_count, episode)
            wandb.log({
                "episode/avg_loss": episode_loss_avg,
                "episode/num_training_steps": len(episode_losses)
            })
            
            # Basic weight logging every LOG_FREQ episodes
            if episode % LOG_FREQ == 0 and episode > 0:
                log_weight_stats(model=main_net, episode=episode)
            
            # Check stopping condition: mean reward instead of max reward
            if mean_reward >= mean_reward_bound:
                max_reward_so_far = max(episode_rewards) if episode_rewards else 0
                print(f"Environment solved in {episode} episodes! Mean reward: {mean_reward:.2f} >= {mean_reward_bound}")
                print(f"Max reward achieved: {max_reward_so_far:.2f}")
                log_solved_episode(episode)
                break
            
            # Save training plot every 1000 episodes
            if episode > 0 and episode % 1000 == 0:
                save_training_plot(str(artifacts_dir), episode_rewards, episode, mean_reward_bound, " Space Invaders")
            
            # Display plot every 100 episodes
            if episode % 100 == 0 and episode > 0:
                avg_reward = np.mean(episode_rewards[-10:]) if len(episode_rewards) >= 10 else np.mean(episode_rewards)
                max_reward_so_far = max(episode_rewards) if episode_rewards else 0
                mean_rewards.append(avg_reward)
                print(f"Episode {episode}, Avg Reward: {avg_reward:.2f}, Mean Reward (100): {mean_reward:.2f}, Max Reward: {max_reward_so_far:.2f}, Epsilon: {epsilon:.3f}, LR: {scheduler.get_last_lr()[0]:.6f}, Buffer: {len(buffer)}, Total Steps: {total_steps}")
                
                display_training_plot(episode_rewards, mean_reward_bound, " Space Invaders")
            
            # Print progress every 10 episodes
            elif episode % 10 == 0 and episode > 0:
                avg_reward = np.mean(episode_rewards[-10:]) if len(episode_rewards) >= 10 else np.mean(episode_rewards)
                max_reward_so_far = max(episode_rewards) if episode_rewards else 0
                print(f"Episode {episode}, Avg Reward: {avg_reward:.2f}, Mean Reward (100): {mean_reward:.2f}, Max Reward: {max_reward_so_far:.2f}, Epsilon: {epsilon:.3f}, LR: {scheduler.get_last_lr()[0]:.6f}, Buffer: {len(buffer)}, Total Steps: {total_steps}")
                
                log_10_episode_average(avg_reward, episode)

            # Save checkpoint every 5000 episodes (more frequent than Defender due to shorter episodes)
            if episode % 5000 == 0 and episode > 0:
                save_checkpoint(str(artifacts_dir), episode, main_net, optimizer, episode_rewards, epsilon, run_id, "space_invaders_dqn_cnn_v1")

            episode += 1
        
        # Log final results
        final_model_path = log_final_results(main_net, episode, mean_reward, episode_rewards, str(artifacts_dir), run_id, "final_space_invaders_dqn_cnn_v1")
        
        print(f"Training completed! All artifacts saved in: {artifacts_dir}")
        print(f"Total steps taken: {total_steps}")
        
        env.close()
        wandb.finish()
        return main_net

# %%
# Test CNN architecture with Space Invaders
env = gym.make('SpaceInvadersNoFrameskip-v4')  # Space Invaders game
state, _ = env.reset()

print(f"Original frame shape: {state.shape}")

processed = preprocess_frame(state)
print(f"Processed frame shape: {processed.shape}")

frame_stack = FrameStack(2)
stacked = frame_stack.reset(state)
print(f"Stacked frames shape: {stacked.shape}")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
cnn_net = ConvDQN(input_channels=2, action_size=env.action_space.n).to(device)

with torch.no_grad():
    state_tensor = torch.FloatTensor(stacked).unsqueeze(0).to(device)
    q_values = cnn_net(state_tensor)
    print(f"Network input shape: {state_tensor.shape}")
    print(f"Q-values shape: {q_values.shape}")
    print(f"Action space size (Space Invaders): {env.action_space.n}")
    print(f"Q-values: {q_values.cpu().numpy()}")

total_params = sum(p.numel() for p in cnn_net.parameters())
print(f"\nTotal parameters: {total_params:,}")

# Show a sample frame to see visual complexity
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
plt.imshow(state)
plt.title('Space Invaders Raw Frame (210x160x3)')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(processed, cmap='gray')
plt.title('Processed Frame (84x84)')
plt.axis('off')
plt.tight_layout()
plt.show()

env.close()
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Original frame shape: (210, 160, 3)
# Processed frame shape: (84, 84)
# Stacked frames shape: (2, 84, 84)
# Network input shape: torch.Size([1, 2, 84, 84])
# Q-values shape: torch.Size([1, 6])
# Action space size (Space Invaders): 6
# Q-values: [[-0.03872422  0.0096414   0.01925767 -0.01441824 -0.03907672 -0.02684595]]
#
# Total parameters: 3,354,278

# %%
# Ensure no active MLflow runs before training
if mlflow.active_run():
    print("Ending active MLflow run...")
    mlflow.end_run()

# Train the CNN-based DQN on Space Invaders
trained_model = train_dqn()
print("Space Invaders CNN-DQN Training completed!")
# Out:
# Episode 4910, Avg Reward: 443.00, Mean Reward (100): 482.30, Max Reward: 1130.00, Epsilon: 0.010, LR: 0.000100, Buffer: 100000, Total Steps: 3422841
# Episode 4920, Avg Reward: 498.50, Mean Reward (100): 486.15, Max Reward: 1130.00, Epsilon: 0.010, LR: 0.000100, Buffer: 100000, Total Steps: 3431147
# Episode 4930, Avg Reward: 553.00, Mean Reward (100): 497.00, Max Reward: 1130.00, Epsilon: 0.010, LR: 0.000100, Buffer: 100000, Total Steps: 3439442
# Episode 4940, Avg Reward: 488.50, Mean Reward (100): 495.40, Max Reward: 1130.00, Epsilon: 0.010, LR: 0.000100, Buffer: 100000, Total Steps: 3446382
# Episode 4950, Avg Reward: 478.50, Mean Reward (100): 487.10, Max Reward: 1130.00, Epsilon: 0.010, LR: 0.000100, Buffer: 100000, Total Steps: 3454131
# Episode 4960, Avg Reward: 530.00, Mean Reward (100): 496.00, Max Reward: 1130.00, Epsilon: 0.010, LR: 0.000100, Buffer: 100000, Total Steps: 3461260
# Episode 4970, Avg Reward: 510.50, Mean Reward (100): 493.05, Max Reward: 1130.00, Epsilon: 0.010, LR: 0.000100, Buffer: 100000, Total Steps: 3468949
# Episode 4980, Avg Reward: 546.00, Mean Reward (100): 498.80, Max Reward: 1130.00, Epsilon: 0.010, LR: 0.000100, Buffer: 100000, Total Steps: 3476708
# 2026/01/10 02:03:04 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Environment solved in 4982 episodes! Mean reward: 500.95 >= 500
# Max reward achieved: 1130.00
# 2026/01/10 02:03:04 WARNING mlflow.utils.requirements_utils: Found torch version (2.10.0.dev20250930+cu128) contains a local version label (+cu128). MLflow logged a pip requirement for this package as 'torch==2.10.0.dev20250930' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 2026/01/10 02:03:08 WARNING mlflow.utils.requirements_utils: Found torch version (2.10.0.dev20250930+cu128) contains a local version label (+cu128). MLflow logged a pip requirement for this package as 'torch==2.10.0.dev20250930' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 2026/01/10 02:03:08 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# Training completed! All artifacts saved in: /home/bmartins/dev/rl_study/artifacts/run_793cfe2b82594e69b2f037948e851fa5
# Total steps taken: 3478196
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>avg_reward_10</td><td>▁▁▃▃▅▅▆▆▅▅▆▅▆▅▇▅▇▇▇▅▇▇▆▇▆▇▆▆▇▇▇▆▇▇▇█▆▇▇█</td></tr><tr><td>bias_norms/conv.0.bias</td><td>▁▁▁▂▂▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇█████████</td></tr><tr><td>bias_norms/conv.2.bias</td><td>▁▁▁▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇█████</td></tr><tr><td>bias_norms/conv.4.bias</td><td>▁▃▃▃▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇█</td></tr><tr><td>bias_norms/fc.0.bias</td><td>▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▇▇▇▇▇▇▇█████</td></tr><tr><td>bias_norms/fc.2.bias</td><td>▁▁▂▂▂▂▂▂▃▃▄▄▄▄▄▄▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇█████</td></tr><tr><td>episode/avg_loss</td><td>▁▁▂▃▃▃▄▅▅▆▆▆▆▆▆▇▇▇▇█▇▇▇▇▆▆▇▇▆██████████▇</td></tr><tr><td>episode/num_training_steps</td><td>▄▂▁▄▅▃▃▂▂▆▄▃▂▄▃▂▄▃▂▃▅▆▄▃▃▃▁▃▂▄▄▂▄▆▅▁█▅▄▄</td></tr><tr><td>final_episode</td><td>▁</td></tr><tr><td>final_mean_reward</td><td>▁</td></tr><tr><td>grad_norms/conv.0.bias</td><td>▇▆▁▇▄▃▂▃▄▂▄▂▅▄▁▅▅▃▅▅▂▄▃█▅▆▄▂▄█▆▅▆█▅▂▄▄▃▅</td></tr><tr><td>grad_norms/conv.0.weight</td><td>▇▅▅▄▃█▆▆█▆▇▅▅▆▃▇▂▃▅█▄▅▇▇▆▁▄▅▆▆▂▄▅▆▅▄▇▃▄▅</td></tr><tr><td>grad_norms/conv.2.bias</td><td>▁█▄▅▇▂▄▅▃▂▂▃▄▂▁▃▂▃▂▄▂▄▂▁▃▄▄▂▃▂▄▅▄▆▇▅▆▅▃▄</td></tr><tr><td>grad_norms/conv.2.weight</td><td>▃▃▂▂▃▁▄▁▃▃▄▅▃▂▄▄▅▅▃▄▄▄▅▄▃▃▆▆▄▆█▆▆▇▄▆▄▇▅█</td></tr><tr><td>grad_norms/conv.4.bias</td><td>▁▃▁▂▃▃▃▂▃▂█▃▇▆▅▆▂▆▆▆▄▅▅▅▄▄▅▄▃▅▇▅▆▆▇▃▆▇▅▆</td></tr><tr><td>grad_norms/conv.4.weight</td><td>▁▂▂▂▂▄▃▄▆▅▄▃▄▃▄▄▂▃█▄▃▃▃▃▅▅▅▄▄█▂▅▃▅▄█▆▅▆▅</td></tr><tr><td>grad_norms/fc.0.bias</td><td>▁▁▁▄▄▂▃▃▆▄▄▃▃▅▂▅▇▆▄▄▄▆▄▄▆█▃▅▅▆▆▅▇▆▄█▇▅▅▆</td></tr><tr><td>grad_norms/fc.0.weight</td><td>▁▂▅▅▄▆█▅▆▅▆▅▅▅▆▅▆▆▅▆▆▅▅▄▅▄▅▇▅▅▇▆▆▇▆▇▆▇▅▇</td></tr><tr><td>grad_norms/fc.2.bias</td><td>▂▅█▄▄▆▅▅▄▃▃▃▃▄▂▂▁▃▃▄▄▄▄▃▃▃▄▁▄▄▄▂▂▄▄▄▃▃▄▄</td></tr><tr><td>grad_norms/fc.2.weight</td><td>▄▁▅▇▆▇▇▇▆██▇▇▆█▅▆▄▆▆▇▄▄▇▆▅▅█▆▆▅▇▇▇▇▇█▅▇▆</td></tr><tr><td>loss</td><td>▂▁▄▁▁▁▃▃▄▁▂▂▃▃▃▁▁▂▂▂▅▃▃▃▂▂▂▁▄▂▃▂▂▂▂▂█▁▅▂</td></tr><tr><td>model_info/conv_parameters</td><td>▁</td></tr><tr><td>model_info/conv_percentage</td><td>▁</td></tr><tr><td>model_info/fc_parameters</td><td>▁</td></tr><tr><td>model_info/fc_percentage</td><td>▁</td></tr><tr><td>model_info/model_size_mb</td><td>▁</td></tr><tr><td>model_info/total_parameters</td><td>▁</td></tr><tr><td>model_info/trainable_parameters</td><td>▁</td></tr><tr><td>solved_at_episode</td><td>▁</td></tr><tr><td>step</td><td>▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇█</td></tr><tr><td>total_episodes</td><td>▁</td></tr><tr><td>training/adaptive_mode</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁████████████▁▁██</td></tr><tr><td>training/episode</td><td>▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇█</td></tr><tr><td>training/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training/target_network_update</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training/total_steps</td><td>▁▁▁▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇█████</td></tr><tr><td>weight_norms/conv.0.weight</td><td>▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇█████</td></tr><tr><td>weight_norms/conv.2.weight</td><td>▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇█████</td></tr><tr><td>weight_norms/conv.4.weight</td><td>▁▁▁▂▂▂▂▃▃▃▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇███</td></tr><tr><td>weight_norms/fc.0.weight</td><td>▁▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇███</td></tr><tr><td>weight_norms/fc.2.weight</td><td>▁▂▂▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇█████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>avg_reward_10</td><td>546</td></tr><tr><td>bias_norms/conv.0.bias</td><td>0.75465</td></tr><tr><td>bias_norms/conv.2.bias</td><td>1.02804</td></tr><tr><td>bias_norms/conv.4.bias</td><td>1 ...
#  View run <strong style="color:#cdcd00">space_invaders_cnn_dqn_v1</strong> at: <a href='https://wandb.ai/bmartins/space_invaders_dqn_training/runs/i52u9frw' target="_blank">https://wandb.ai/bmartins/space_invaders_dqn_training/runs/i52u9frw</a><br> View project at: <a href='https://wandb.ai/bmartins/space_invaders_dqn_training' target="_blank">https://wandb.ai/bmartins/space_invaders_dqn_training</a><br>Synced 5 W&B file(s), 4 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>/home/bmartins/dev/rl_study/wandb/wandb/run-20260109_221744-i52u9frw/logs</code>
# Space Invaders CNN-DQN Training completed!
